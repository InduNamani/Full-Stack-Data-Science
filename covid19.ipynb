# %% [markdown]
# # pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the main COVID-19 data file
df = pd.read_csv(r'C:\Users\indun\Downloads\archive (2)\covid_19_clean_complete.csv')

# OR load country-wise data
# df = pd.read_csv(r'C:\Users\indun\Downloads\covid_data\country_wise_latest.csv')

# Check what you got
print("Column names:")
print(df.columns.tolist())
print("\nFirst 5 rows:")
print(df.head())
print(f"\nDataset shape: {df.shape}")
print("\nData types:")
print(df.dtypes)
# Out:
# Column names:
# ['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region']
#
# First 5 rows:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa
#
# Dataset shape: (49068, 10)
#
# Data types:
# ...

# %%
print("\nData Types:")
print(df.dtypes)

# Dataset info
print("\nDataset Info:")
print(df.info())

# Check null values
print("\nMissing Values:")
print(df.isnull().sum())

# Statistical summary
print("\nStatistical Summary:")
print(df.describe())

# Check unique values
print(f"\nNumber of unique countries: {df['Country/Region'].nunique()}")
print(f"Number of unique dates: {df['Date'].nunique()}")
# Out:
# Data Types:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# ...

# %% [markdown]
# # Numpy

# %%
print("\nData Types:")
print(df.dtypes)

# Dataset info
print("\nDataset Info:")
print(df.info())

# Check null values
print("\nMissing Values:")
print(df.isnull().sum())

# Statistical summary
print("\nStatistical Summary:")
print(df.describe())

# Check unique values
print(f"\nNumber of unique countries: {df['Country/Region'].nunique()}")
print(f"Number of unique dates: {df['Date'].nunique()}")
# Out:
# Data Types:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# ...

# %% [markdown]
# # Matplotlib

# %%
plt.figure(figsize=(12, 6))
top_10 = country_stats.sort_values('Confirmed', ascending=False).head(10)
plt.bar(top_10['Country/Region'], top_10['Confirmed'], color='coral', edgecolor='black')
plt.title('Top 10 Countries by Confirmed Cases', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12)
plt.ylabel('Confirmed Cases', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.figure(figsize=(12, 6))
# ----> 2 top_10 = country_stats.sort_values('Confirmed', ascending=False).head(10)
#       3 plt.bar(top_10['Country/Region'], top_10['Confirmed'], color='coral', edgecolor='black')
#       4 plt.title('Top 10 Countries by Confirmed Cases', fontsize=14, fontweight='bold')
#
# NameError: name 'country_stats' is not defined
